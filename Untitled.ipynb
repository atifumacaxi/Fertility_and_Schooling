# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_education = pd.read_csv('./raw_data/education.csv', sep=';')
df_fertility = pd.read_csv('./raw_data/education.csv', sep=';')

df_education.head()
# Out:
#         Entity Code  Year  avg_years_of_schooling
# 0  Afghanistan  AFG  1870                    0.01
# 1  Afghanistan  AFG  1875                    0.01
# 2  Afghanistan  AFG  1880                    0.01
# 3  Afghanistan  AFG  1885                    0.01
# 4  Afghanistan  AFG  1890                    0.01

# %%
plt.plot('Year', 'avg_years_of_schooling', data=df_education)

# %%
sns.histplot(data=df_education, x='Year', y='avg_years_of_schooling', hue='Entity')
# Out:
# <Axes: xlabel='Year', ylabel='avg_years_of_schooling'>
